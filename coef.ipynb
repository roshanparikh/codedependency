# %%
import pickle as pkl
import plotly.express as px
import os, sys
from os.path import join

# %%
file_path = join("output", 'shap', 'model_results_all_30', 'SVC Linear', 
                 'shap_model_results_all_30_SVC Linear.pkl')
with open(file_path, 'rb') as f:
    res = pkl.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 file_path = join("output", 'model_results_all_30', 'SVC Linear',
#       2                  'shap_model_results_all_30_SVC Linear.pkl')
# ----> 3 with open(file_path, 'rb') as f:
#       4     res = pkl.load(f)
#
# File ~/Documents/Sinai/Research/codedependency/.venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# ...

# %%
res
